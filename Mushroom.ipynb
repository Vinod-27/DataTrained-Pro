# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\veenu\Data Science\Mushroom.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# # EDA(Explotary Data Analysis)

# %%
columns=['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
for c in columns:
    print(c,(len(df[c].value_counts())))
# Out:
# class 2
# cap-shape 6
# cap-surface 4
# cap-color 10
# bruises 2
# odor 9
# gill-attachment 2
# gill-spacing 2
# gill-size 2
# gill-color 12
# stalk-shape 2
# stalk-root 5
# stalk-surface-above-ring 4
# stalk-surface-below-ring 4
# stalk-color-above-ring 9
# stalk-color-below-ring 9
# veil-type 1
# veil-color 4
# ring-number 3
# ring-type 5
# spore-print-color 9
# population 6
# habitat 7

# %% [raw]
# Total columns are Classified&also label is also Classified,So the problem is Classification problem

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [raw]
# All factors are in object data,So I hve to convert data into Numeric

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
columns=['class','cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
for c in df[columns]:
    df[c]=le.fit_transform(df[c].astype(str))

df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           8  ...
# 1                   1             0          0           8  ...
# ...

# %% [raw]
# In features we can apply three methods for Encoding i,e Onehotencoder,get_dummies,Labelecndoer But Here I applied LabelEncoder
# on dataset,Because so may columns in features

# %%
df.dtypes
# Out:
# class                       int32
# cap-shape                   int32
# cap-surface                 int32
# cap-color                   int32
# bruises                     int32
# odor                        int32
# gill-attachment             int32
# gill-spacing                int32
# gill-size                   int32
# gill-color                  int32
# stalk-shape                 int32
# stalk-root                  int32
# stalk-surface-above-ring    int32
# stalk-surface-below-ring    int32
# stalk-color-above-ring      int32
# stalk-color-below-ring      int32
# veil-type                   int32
# veil-color                  int32
# ring-number                 int32
# ring-type                   int32
# spore-print-color           int32
# population                  int32
# habitat                     int32
# dtype: object

# %% [raw]
# Now all factors&Label are in Numeric

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [raw]
# No null values present

# %%
sns.heatmap(df.isnull())

# %% [raw]
# In heatmap no null values are visible

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)

# %%
Correaltion of dataset

# %%
df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %%
Skewness is present in some columns

# %%
columns=['class','cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

for c in columns:
    if df[c].skew() >0.5 or df[c].skew() < -0.5:
        print(c,df[c].skew())
        sns.distplot(df[c])
        plt.show()
# Out:
# cap-surface -0.5908588458299506
# cap-color 0.7069648306800983
# gill-attachment -5.977076338335794
# gill-spacing 1.8400882459138057
# gill-size 0.8257968918825481
# stalk-root 0.947852361187689
# stalk-surface-above-ring -1.098739385017716
# stalk-surface-below-ring -0.7577031799233366
# stalk-color-above-ring -1.835434372564438
# stalk-color-below-ring -1.7915934221991003
# veil-color -6.946943928461256
# ring-number 2.701657257979159
# spore-print-color 0.54842584442875
# population -1.4130956760143683
# habitat 0.9855476723148265

# %%
In this we can see the skewness of columns in visualisation

# %%
df.iloc[:,:13].boxplot(figsize=(22,10))

# %%
df.iloc[:,13:23].boxplot(figsize=(22,10))

# %%
df.plot(kind="box",subplots=True,layout=(3,10))
# Out:
# class                          AxesSubplot(0.125,0.657941;0.065678x0.222059)
# cap-shape                   AxesSubplot(0.203814,0.657941;0.065678x0.222059)
# cap-surface                 AxesSubplot(0.282627,0.657941;0.065678x0.222059)
# cap-color                   AxesSubplot(0.361441,0.657941;0.065678x0.222059)
# bruises                     AxesSubplot(0.440254,0.657941;0.065678x0.222059)
# odor                        AxesSubplot(0.519068,0.657941;0.065678x0.222059)
# gill-attachment             AxesSubplot(0.597881,0.657941;0.065678x0.222059)
# gill-spacing                AxesSubplot(0.676695,0.657941;0.065678x0.222059)
# gill-size                   AxesSubplot(0.755508,0.657941;0.065678x0.222059)
# gill-color                  AxesSubplot(0.834322,0.657941;0.065678x0.222059)
# stalk-shape                    AxesSubplot(0.125,0.391471;0.065678x0.222059)
# stalk-root                  AxesSubplot(0.203814,0.391471;0.065678x0.222059)
# ...

# %%
This shows the outliers of some columns

# %%
sns.pairplot(df)

# %% [markdown]
# # Data Cleaning

# %%
# from scipy.stats import zscore
# zscr=np.abs(zscore(df))

# threshold=3
# print(np.where(zscr>3))

# %%
# len(zscr[0])

# %%
# zscr[1816][15]

# %%
# print("before outliers removed",df.shape)
# dfn=df[(zscr<3).all(axis=1)]
# print("after outliers removed",dfn.shape)

# %%
columns=['class','cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
for c in df[columns]:
    sns.countplot(df[c])
    plt.show()

# %% [raw]
# In Classified columns we cannot remove the outliers&skewness because the data in some columns are range and some columns
# are in not range,So when columns have does not range we need to drop that columns or do check is correlate with target or not
# else we can keep that column,Its depend upon DataScientist
# Here I didn't dropped any column ,I gave owl dataset to training as well as testing

# %%
X=df.drop('class',axis=1)

# %%
Y=df['class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.30,random_state=45)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
lg=LogisticRegression()
lg.fit(X_train,Y_train)
pred=lg.predict(X_test)     
print(accuracy_score(Y_test,pred))
# Out:
# 0.9474979491386383

# %% [raw]
# The Model gives 94% accuracy without cleaning data
