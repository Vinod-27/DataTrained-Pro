# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import warnings
warnings.filterwarnings
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %%
df=pd.read_csv(r"C:\\Users\\veenu\Datasets\\Temparature.csv")

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %% [markdown]
# # Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %% [markdown]
# # Explotary Data Analysis

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [raw]
# So much columns have Null values

# %%
for i in ['station','Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
       'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
       'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin']:
    sns.distplot(df[i])
    plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
df.iloc[:,:13].head(3)
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  LDAPS_CC1  \
# 0         28.074101         23.006936  6.818887  69.451805   0.233947
# 1         29.850689         24.035009  5.691890  51.937448   0.225508
# 2         30.091292         24.565633  6.138224  20.573050   0.209344
#
#    LDAPS_CC2  LDAPS_CC3
# 0   0.203896   0.161697
# 1   0.251771   0.159444
# 2   0.257469   0.204091

# %%
df.iloc[:,13:25].head(3)
# Out:
#    LDAPS_CC4  LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat  \
# 0   0.130928         0.0         0.0         0.0         0.0  37.6046
# 1   0.127727         0.0         0.0         0.0         0.0  37.6046
# 2   0.142125         0.0         0.0         0.0         0.0  37.5776
#
#        lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0  126.991  212.3350  2.7850      5992.895996       29.1       21.2
# 1  127.032   44.7624  0.5141      5869.312500       30.5       22.5
# 2  127.058   33.3068  0.2661      5863.555664       31.1       23.9

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
for i in ['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
       'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
       'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
       'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'Next_Tmax', 'Next_Tmin']:
    df[i]=df[i].replace(np.NaN,df[i].mean())

# %% [raw]
# I replaced null values to mean of most repeated values in that particular columns

# %%
df.isnull().sum()
# Out:
# station             0
# Date                2
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
df['Date']=df['Date'].replace(np.NaN,0)

# %% [raw]
# I Reaplaced null values to 0

# %%
df['Date'].isnull().sum()
# Out:
# 0

# %%
d=pd.to_datetime(df['Date']).dt.day
m=pd.to_datetime(df['Date']).dt.month
y=pd.to_datetime(df['Date']).dt.year

# %%
df.shape
# Out:
# (7752, 25)

# %%
new={}
df['Day']=d
df['Month']=m
df['Year']=y
t=pd.DataFrame(new)

# %%
dn=pd.concat([df,d],axis=1)

# %%
dn.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Day',
#        'Month', 'Year', 'Date'],
#       dtype='object')

# %%
dn.drop('Date',axis=1,inplace=True)

# %%
dn.iloc[:,:14].head(3)
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  LDAPS_CC1  \
# 0         28.074101         23.006936  6.818887  69.451805   0.233947
# 1         29.850689         24.035009  5.691890  51.937448   0.225508
# 2         30.091292         24.565633  6.138224  20.573050   0.209344
#
#    LDAPS_CC2  LDAPS_CC3  LDAPS_CC4  LDAPS_PPT1
# 0   0.203896   0.161697   0.130928         0.0
# 1   0.251771   0.159444   0.127727         0.0
# 2   0.257469   0.204091   0.142125         0.0

# %%
dn.iloc[:,14:28].head(3)
# Out:
#    LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0         0.0  37.5776  127.058   33.3068  0.2661
#
#    Solar radiation  Next_Tmax  Next_Tmin  Day  Month  Year
# 0      5992.895996       29.1       21.2   30      6  2013
# 1      5869.312500       30.5       22.5   30      6  2013
# 2      5863.555664       31.1       23.9   30      6  2013

# %%
for i in ['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
       'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
       'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
       'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
       'Solar radiation', 'Next_Tmax', 'Next_Tmin', 'Day', 'Month', 'Year']:
    if df[i].skew()>0.5 or df[i].skew()<-0.5:
        sns.distplot(df[i])
        plt.show()

# %% [raw]
# Above Graphical Representation is for skewness of columns

# %%
df.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.264137
# Present_Tmin       -0.367538
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -0.855015
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_WS            1.579236
# LDAPS_LH            0.673757
# LDAPS_CC1           0.459458
# LDAPS_CC2           0.472350
# LDAPS_CC3           0.640735
# LDAPS_CC4           0.666482
# LDAPS_PPT1          5.393821
# LDAPS_PPT2          5.775355
# LDAPS_PPT3          6.457129
# LDAPS_PPT4          6.825464
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.340200
# Next_Tmin          -0.404447
# Day                 0.244954
# Month              -0.706382
# Year               -5.849888
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
df['LDAPS_RHmax']=pt.fit_transform(pd.DataFrame(df['LDAPS_RHmax']))
df['LDAPS_Tmin_lapse']=pt.fit_transform(pd.DataFrame(df['LDAPS_Tmin_lapse']))
df['LDAPS_WS']=pt.fit_transform(pd.DataFrame(df['LDAPS_WS']))
df['LDAPS_LH']=pt.fit_transform(pd.DataFrame(df['LDAPS_LH']))
df['LDAPS_CC3']=pt.fit_transform(pd.DataFrame(df['LDAPS_CC3']))
df['LDAPS_CC4']=pt.fit_transform(pd.DataFrame(df['LDAPS_CC4']))
df['LDAPS_PPT1']=pt.fit_transform(pd.DataFrame(df['LDAPS_PPT1']))
df['LDAPS_PPT2']=pt.fit_transform(pd.DataFrame(df['LDAPS_PPT2']))
df['LDAPS_PPT3']=pt.fit_transform(pd.DataFrame(df['LDAPS_PPT3']))
df['LDAPS_PPT4']=pt.fit_transform(pd.DataFrame(df['LDAPS_PPT4']))
df['lat']=pt.fit_transform(pd.DataFrame(df['lat']))
df['DEM']=pt.fit_transform(pd.DataFrame(df['DEM']))
df['Slope']=pt.fit_transform(pd.DataFrame(df['Slope']))
df['Solar radiation']=pt.fit_transform(pd.DataFrame(df['Solar radiation']))
df['Month']=pt.fit_transform(pd.DataFrame(df['Month']))
df['Year']=pt.fit_transform(pd.DataFrame(df['Year']))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2995: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:195: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:199: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)

# %% [raw]
# I Applied PowerTransformation for Removing Skewness

# %%
df.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.264137
# Present_Tmin       -0.367538
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -0.115143
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.017827
# LDAPS_WS            0.002408
# LDAPS_LH            0.057403
# LDAPS_CC1           0.459458
# LDAPS_CC2           0.472350
# LDAPS_CC3           0.087933
# LDAPS_CC4           0.126895
# LDAPS_PPT1          1.404189
# LDAPS_PPT2          1.577808
# LDAPS_PPT3          1.747820
# LDAPS_PPT4          1.963848
# lat                 0.000000
# lon                -0.285213
# DEM                 0.039456
# Slope               0.233968
# Solar radiation    -0.176636
# Next_Tmax          -0.340200
# Next_Tmin          -0.404447
# Day                 0.244954
# Month               0.042946
# Year               -1.700047
# dtype: float64

# %% [markdown]
# TMinimum Target Variable

# %%
x=dn.drop(['Next_Tmax','Next_Tmin'],axis=1)

# %%
y=df['Next_Tmin']

# %% [markdown]
# TMaximum Target Variable

# %%
X=dn.drop(['Next_Tmax','Next_Tmin'],axis=1)

# %%
Y=df['Next_Tmax']

# %% [markdown]
# # Model generation

# %% [markdown]
# Minimum Target Variable

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

best_state=0
accu=0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.30, 
                                                    random_state=i)
    l = LinearRegression()
    l.fit(x_train,y_train)
    predictions = l.predict(x_test)
    accuracy=r2_score(y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.8426333771629417 and best random state is 103

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predictions))
print('Mean squared error:',mean_squared_error(y_test,predictions))

print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,predictions)))
# Out:
# error:
# Mean absolute error: 0.7712551844873526
# Mean squared error: 0.9698141288242761
# Root Mean Squared error: 0.984791413866041

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=50)

# %%
from sklearn.model_selection import GridSearchCV 
# from sklearn.ensemble import RandomForestRegressor
# para={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
# rf=RandomForestRegressor()
# clf=GridSearchCV(rf,para)
# clf.fit(x_train,y_train)     
# print(clf.best_params_)

# %%
# rf=RandomForestRegressor(criterion='mae',max_features='auto')
# rf.fit(x_train,y_train)
# rf.score(x_train,y_train)
# pred=rf.predict(x_test)
# rfs=r2_score(y_test,pred) 
# print("R2 Score",rfs)

# %%
from sklearn.tree import DecisionTreeRegressor
d=DecisionTreeRegressor()            #(criterion={"mse", "friedman_mse", "mae"},splitter={"best","random"})
para={'criterion':["mse", "friedman_mse", "mae"],'splitter':["best","random"]}
d=DecisionTreeRegressor()
cl=GridSearchCV(d,para)
cl.fit(x_train,y_train)
print(cl.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
d=DecisionTreeRegressor(criterion='friedman_mse',splitter='best')
d.fit(x_train,y_train)
pred=d.predict(x_test)
dt=r2_score(y_test,pred)
print(dt)
# Out:
# 0.7704348732746562

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
#ls=Lasso(aplha=1.0 )#Default
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.832437987181333

# %%
rd=Ridge(alpha=0.0001)
#rd=Ridge()
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.8324395648020265

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
#enr=ElascticNet()
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.8324384722297603
# array([-1.81129633e-03,  3.49766999e-02,  2.57697709e-01,  1.82247166e-02,
#         4.33003969e-03,  8.99584000e-02,  6.19851755e-01,  1.61474582e-02,
#         5.63106088e-04, -4.18863623e-01,  3.72544082e-01, -5.61796988e-01,
#         1.93103597e-01, -3.37341314e-02, -3.16875442e-02,  5.67874289e-02,
#        -6.96154156e-02, -9.27596194e-01, -6.35603216e-01, -7.70836167e-03,
#         2.45158016e-01,  9.31042225e-05,  1.05737289e-02, -3.14619207e-03,
#         1.04710060e-02])

# %% [markdown]
# Maximum Target Variable

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression
l=LinearRegression()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

best_state=0
accu=0
for i in range(1,200):
    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.30, 
                                                    random_state=i)
    l = LinearRegression()
    l.fit(X_train,Y_train) 
    predictions = l.predict(X_test)
    accuracy=r2_score(Y_test,predictions)
    if accuracy>accu:
        accu=accuracy
        best_state=i
print(f"Final accuracy is{accu} and best random state is {best_state}")
# Out:
# Final accuracy is0.7878939209126562 and best random state is 120

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print('error:')
print('Mean absolute error:',mean_absolute_error(Y_test,predictions))
print('Mean squared error:',mean_squared_error(Y_test,predictions))

print('Root Mean Squared error:',np.sqrt(mean_squared_error(Y_test,predictions)))
# Out:
# error:
# Mean absolute error: 1.090908495514869
# Mean squared error: 2.1083822690521035
# Root Mean Squared error: 1.4520269519027886

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=.30,random_state=50)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
d=DecisionTreeRegressor()            #(criterion={"mse", "friedman_mse", "mae"},splitter={"best","random"})
para={'criterion':["mse", "friedman_mse", "mae"],'splitter':["best","random"]}
d=DecisionTreeRegressor()
cl=GridSearchCV(d,para)
cl.fit(X_train,Y_train)  
print(cl.best_params_)
# Out:
# {'criterion': 'mse', 'splitter': 'random'}

# %%
d=DecisionTreeRegressor(criterion='mse',splitter='best')
d.fit(X_train,Y_train)
pred=d.predict(X_test)
dt=r2_score(Y_test,pred)
print(dt)
# Out:
# 0.7610662697182321

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
#ls=Lasso(aplha=1.0 )#Default
ls.fit(X_train,Y_train)
ls.score(X_train,Y_train)
# Out:
# 0.7771413284570589

# %%
rd=Ridge(alpha=0.0001)
#rd=Ridge()
rd.fit(X_train,Y_train)
rd.score(X_train,Y_train)
# Out:
# 0.7771419324656613

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.0001)
#enr=ElascticNet()
enr.fit(X_train,Y_train)
enrpred=enr.predict(X_test)
print(enr.score(X_train,Y_train))
enr.coef_
# Out:
# 0.7771413210464713
# array([ 1.92511763e-02,  1.65751665e-01,  4.71874354e-02,  2.29658901e-02,
#         3.20980106e-03,  6.19831938e-01,  7.27979051e-02, -1.56053562e-01,
#         6.57597875e-03, -1.07896011e+00, -7.66257939e-01, -9.43789150e-01,
#        -1.05004940e+00,  7.03098657e-03,  1.19644682e-01, -1.55080274e-02,
#        -3.04011977e-03, -7.54130278e-01, -1.81103550e+00, -3.78108304e-03,
#         1.62924785e-01,  3.16212663e-05,  5.72932459e-03, -4.07445433e-02,
#         6.11625121e-02])

# %% [markdown]
# # Conclusion :
# The Best Model for Tmax is LinearRegression with 84% accuracy
#
# The Best Model for Tmin is LinearRegression with 84% accuracy

# %%
import pickle
filename='Tmaxmin.pkl'
pickle.dump(l,open(filename,'wb'))
